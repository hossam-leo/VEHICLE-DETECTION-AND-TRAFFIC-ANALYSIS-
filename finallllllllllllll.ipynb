# %% [markdown]
# # YOLOv8 Vehicle Detection - Full Dataset Pipeline (Kaggle)
# This notebook implements a complete YOLOv8 pipeline optimized for Kaggle. It automatically handles dataset extraction, detects structure, and trains on the **full dataset** without any sampling.

# %%
# !pip install ultralytics opencv-python --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.5 MB/s eta 0:00:0000:0100:01

# %%
import os
import random
import shutil
import zipfile
import yaml
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from ultralytics import YOLO
from IPython.display import Image, display

# Set random seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Automatically detect GPU
device = 0 if torch.cuda.is_available() else -1
print(f"Execution Device: {'GPU' if device == 0 else 'CPU'}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Execution Device: GPU

# %% [markdown]
# ## 1. Dataset Handling
# Extracting and preparing the full dataset from `/kaggle/input/my-dataset/dataset.zip`.

# %%
# Path to your dataset based on the screenshot
dataset_input_dir = Path('/kaggle/input/datasets/hossammostafa25/hosssssss')

if not dataset_input_dir.exists():
    # Fallback search if the name differs slightly
    print("Target path not found, searching /kaggle/input...")
    potential_paths = list(Path('/kaggle/input').rglob('train'))
    if potential_paths:
        dataset_input_dir = potential_paths[0].parent
    else:
        raise FileNotFoundError("Could not find dataset in /kaggle/input. Please check the 'Input' section on the right.")

print(f"Dataset found at: {dataset_input_dir}")

# Load class names from existing data.yaml
class_names = {0: 'vehicle'} # Default
existing_yaml = dataset_input_dir / 'data.yaml'
if existing_yaml.exists():
    with open(existing_yaml, 'r') as f:
        data = yaml.safe_load(f)
        if 'names' in data: 
            class_names = data['names']
            print("Loaded class names from dataset data.yaml.")

# Create the Kaggle-specific data.yaml in the working directory
# We map 'valid' to 'val' as YOLOv8 expects
data_yaml_content = {
    'path': str(dataset_input_dir.resolve()),
    'train': 'train/images',
    'val': 'valid/images',
    'test': 'test/images',
    'names': class_names
}

working_yaml = '/kaggle/working/data.yaml'
with open(working_yaml, 'w') as f:
    yaml.dump(data_yaml_content, f)

print(f"Configuration saved to {working_yaml}")
# Out:
# Dataset found at: /kaggle/input/datasets/hossammostafa25/hosssssss
# Loaded class names from dataset data.yaml.
# Configuration saved to /kaggle/working/data.yaml

# %% [markdown]
# ## 2. Model Training
# Training YOLOv8n on the full dataset for 30 and 50 epochs.

# %%
PARAMS = {'data': working_yaml, 'imgsz': 640, 'batch': 16, 'device': device, 'project': '/kaggle/working/runs', 'seed': SEED}

print("\n--- Training: 30 Epochs ---")
model_30 = YOLO('yolov8n.pt')
model_30.train(epochs=30, name='exp_30', **PARAMS)

print("\n--- Training: 50 Epochs ---")
model_50 = YOLO('yolov8n.pt')
model_50.train(epochs=50, name='exp_50', **PARAMS)
# Out:
# --- Training: 30 Epochs ---
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 75.0MB/s 0.1s
# New https://pypi.org/project/ultralytics/8.4.43 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.42 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_30, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/exp_30, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 14.1MB/s 0.1s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 69.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.7±0.4 ms, read: 13.9±2.2 MB/s, size: 47.2 KB)
# train: Scanning /kaggle/input/datasets/hossammostafa25/hosssssss/train/labels... 20409 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20409/20409 326.8it/s 1:02<0.0ss
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/hossammostafa25/hosssssss/train is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.3±0.6 ms, read: 7.8±3.4 MB/s, size: 58.8 KB)
# val: Scanning /kaggle/input/datasets/hossammostafa25/hosssssss/valid/labels... 1939 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1939/1939 350.3it/s 5.5s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/hossammostafa25/hosssssss/valid is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/exp_30/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/exp_30
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.51G      1.374      1.256      1.163        133        640: 100% ━━━━━━━━━━━━ 1276/1276 5.7it/s 3:43<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 4.5it/s 13.5s0.2s
#                    all       1939      17899       0.84      0.756      0.833      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.85G      1.242     0.8448      1.124        128        640: 100% ━━━━━━━━━━━━ 1276/1276 5.9it/s 3:35<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.0it/s 12.1s0.2s
#                    all       1939      17899      0.848      0.819      0.877      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.85G      1.205     0.7818      1.116         73        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:31<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.872      0.835      0.905      0.706
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.85G      1.172     0.7405      1.104        123        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:31<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.893      0.856      0.921       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      3.23G      1.125     0.6957      1.087         93        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.861      0.875      0.915      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      3.23G      1.089     0.6644       1.07        134        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899       0.88      0.876      0.929      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      3.23G      1.063     0.6432      1.058        112        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.903      0.876      0.938      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      3.23G      1.039     0.6253      1.048         89        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.921      0.886      0.951      0.778
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      3.23G      1.027     0.6075      1.044        122        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.919      0.894      0.953      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      3.23G      1.011     0.5955      1.039        194        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899       0.92      0.904      0.953      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      3.23G     0.9958      0.583      1.031         66        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899       0.92      0.907      0.955      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      3.23G     0.9794     0.5719      1.024        109        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.0it/s 12.1s0.2s
#                    all       1939      17899      0.928      0.902      0.959      0.799
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      3.23G     0.9727     0.5627      1.022        111        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:33<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.919      0.917      0.959      0.799
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      3.23G     0.9569     0.5524      1.015        122        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.933      0.911      0.962      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      3.23G     0.9503     0.5435      1.012        156        640: 100% ━━━━━━━━━━━━ 1276/1276 6.1it/s 3:31<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.928      0.917      0.965      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      3.23G     0.9394     0.5372      1.009        113        640: 100% ━━━━━━━━━━━━ 1276/1276 6.1it/s 3:31<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.931      0.915      0.966      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      3.23G     0.9294     0.5288      1.004        125        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.927      0.925      0.968      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      3.23G     0.9209     0.5229     0.9995         98        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.933      0.928      0.969      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      3.23G     0.9139     0.5148     0.9975         91        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.933      0.936       0.97      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      3.23G     0.9032     0.5062      0.991        167        640: 100% ━━━━━━━━━━━━ 1276/1276 6.0it/s 3:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.941      0.923       0.97      0.824
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      3.23G     0.8999     0.4557      1.001         88        640: 100% ━━━━━━━━━━━━ 1276/1276 6.1it/s 3:29<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.935      0.931      0.971      0.823
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      3.23G     0.8817     0.4445      0.992         78        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:26<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.938      0.939      0.973      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      3.23G     0.8705     0.4373     0.9878         61        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.944      0.933      0.973      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      3.23G     0.8616     0.4301     0.9832         55        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:25<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.947      0.933      0.974      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      3.23G     0.8503     0.4235     0.9779         95        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:25<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.941      0.943      0.975      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      3.23G     0.8422     0.4171      0.973        110        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:26<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.951      0.934      0.976      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      3.23G     0.8311     0.4111     0.9689         56        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.948      0.939      0.976      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      3.23G     0.8244     0.4055     0.9671         54        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:26<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.954      0.937      0.976      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      3.23G     0.8169     0.4001     0.9631         66        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:27<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.1s0.2s
#                    all       1939      17899      0.948      0.943      0.976      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      3.23G     0.8112     0.3962     0.9618         81        640: 100% ━━━━━━━━━━━━ 1276/1276 6.2it/s 3:26<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.952      0.941      0.977      0.839
#
# 30 epochs completed in 1.857 hours.
# Optimizer stripped from /kaggle/working/runs/exp_30/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/runs/exp_30/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/runs/exp_30/weights/best.pt...
# Ultralytics 8.4.42 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 4.5it/s 13.4s0.2s
#                    all       1939      17899      0.948      0.942      0.976      0.839
#                    bus        291        312      0.949      0.957      0.978      0.842
#                    car       1920      14723      0.957      0.941      0.984      0.809
#                  truck        860       1353      0.918       0.89       0.95      0.804
#                    van        792       1511      0.967      0.981      0.993        0.9
# Speed: 0.2ms preprocess, 2.0ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /kaggle/working/runs/exp_30
#
# --- Training: 50 Epochs ---
# New https://pypi.org/project/ultralytics/8.4.43 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.42 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_50, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/exp_50, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 88.8±15.6 MB/s, size: 46.3 KB)
# train: Scanning /kaggle/input/datasets/hossammostafa25/hosssssss/train/labels... 20409 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20409/20409 664.9it/s 30.7s<0.1s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/hossammostafa25/hosssssss/train is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.2±0.2 ms, read: 105.2±42.7 MB/s, size: 63.7 KB)
# val: Scanning /kaggle/input/datasets/hossammostafa25/hosssssss/valid/labels... 1939 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1939/1939 541.6it/s 3.6s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/hossammostafa25/hosssssss/valid is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/exp_50/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/exp_50
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.56G      1.394      1.417      1.188        133        640: 100% ━━━━━━━━━━━━ 1276/1276 3.8it/s 5:35<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 4.7it/s 13.0s0.2s
#                    all       1939      17899      0.833       0.77      0.835       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.91G      1.246     0.9108       1.12        128        640: 100% ━━━━━━━━━━━━ 1276/1276 4.5it/s 4:41<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 4.9it/s 12.5s0.2s
#                    all       1939      17899      0.809      0.795      0.851      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.91G      1.244     0.8516      1.133         73        640: 100% ━━━━━━━━━━━━ 1276/1276 4.9it/s 4:20<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.0it/s 12.2s0.2s
#                    all       1939      17899      0.843       0.82      0.875      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.91G      1.226     0.8086      1.134        123        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:14<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.0it/s 12.1s0.2s
#                    all       1939      17899      0.887      0.821      0.891      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      3.29G      1.163     0.7402      1.108         93        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.0it/s 12.1s0.2s
#                    all       1939      17899      0.881      0.859      0.915      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      3.29G      1.118      0.696      1.087        134        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.889      0.868      0.921      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      3.29G      1.087     0.6674      1.072        112        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.895      0.862      0.929      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      3.29G      1.058     0.6464       1.06         89        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.909       0.89      0.945      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      3.29G       1.04     0.6252      1.052        122        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.915       0.89      0.949      0.777
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      3.29G      1.025     0.6113      1.047        194        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.927      0.896       0.95      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      3.29G       1.01     0.5979      1.037         66        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.925      0.895      0.956      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.29G      0.994     0.5863      1.032        109        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.932      0.896      0.957      0.792
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      3.29G     0.9874     0.5767       1.03        111        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:11<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.928      0.912      0.962      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      3.29G     0.9714     0.5667      1.023        122        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:11<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.934      0.912      0.964      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      3.29G     0.9671     0.5601       1.02        156        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.938      0.911      0.964      0.805
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      3.29G     0.9568     0.5531      1.017        113        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.939      0.907      0.963      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      3.29G      0.948     0.5457      1.013        125        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.932      0.918      0.966      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      3.29G     0.9424     0.5413      1.009         98        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.0it/s 12.1s0.2s
#                    all       1939      17899      0.937      0.922      0.966      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      3.29G     0.9352     0.5339      1.007         91        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.0it/s 12.1s0.2s
#                    all       1939      17899       0.93      0.931      0.968      0.817
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      3.29G     0.9271     0.5271      1.002        167        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:14<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.933      0.929      0.968      0.817
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      3.29G     0.9206     0.5219          1        104        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.937      0.932       0.97      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      3.29G     0.9181     0.5182     0.9996         90        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.945      0.929       0.97       0.82
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      3.29G     0.9133     0.5152     0.9971        187        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.941      0.929       0.97      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      3.29G     0.9053     0.5093     0.9945        171        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.1s0.2s
#                    all       1939      17899      0.945      0.937      0.973      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      3.29G     0.9009     0.5066     0.9922        118        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.948      0.935      0.972      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      3.29G     0.8952     0.5012     0.9897        148        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.946      0.938      0.973      0.833
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      3.29G     0.8912     0.4976     0.9865        125        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.949      0.934      0.974      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      3.29G     0.8889     0.4929     0.9871        130        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.954      0.927      0.976      0.837
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      3.29G     0.8821     0.4879     0.9839         84        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.947      0.939      0.976      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      3.29G     0.8761      0.484      0.982         94        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.954      0.937      0.977       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      3.29G     0.8717     0.4821     0.9807         82        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.956      0.931      0.977       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      3.29G     0.8674     0.4781      0.976        166        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.952      0.934      0.977      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      3.29G     0.8631     0.4744     0.9772         99        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.952      0.936      0.977       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      3.29G     0.8579      0.469     0.9738        122        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:12<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.955      0.936      0.977      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      3.29G     0.8541     0.4672     0.9718        106        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.949      0.944      0.978      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      3.29G     0.8495     0.4647     0.9701        139        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.957      0.936      0.978      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      3.29G     0.8432     0.4608     0.9688        117        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.942      0.949      0.978      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      3.29G     0.8401     0.4574     0.9667         92        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.1s0.2s
#                    all       1939      17899       0.95      0.939      0.978      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      3.29G     0.8342      0.453     0.9644        146        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.952      0.941      0.979      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      3.29G     0.8287       0.45     0.9604        113        640: 100% ━━━━━━━━━━━━ 1276/1276 5.0it/s 4:13<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.953      0.945      0.979      0.845
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      3.29G     0.8333     0.4055     0.9695         62        640: 100% ━━━━━━━━━━━━ 1276/1276 5.2it/s 4:07<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.8s0.2s
#                    all       1939      17899      0.951      0.945       0.98      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      3.29G     0.8183     0.3987     0.9636         39        640: 100% ━━━━━━━━━━━━ 1276/1276 5.2it/s 4:06<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.1s0.2s
#                    all       1939      17899      0.954      0.942       0.98      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      3.29G     0.8093     0.3919     0.9581         69        640: 100% ━━━━━━━━━━━━ 1276/1276 5.1it/s 4:08<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.1s0.2s
#                    all       1939      17899      0.957       0.94       0.98      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      3.29G     0.8036     0.3884     0.9568        116        640: 100% ━━━━━━━━━━━━ 1276/1276 5.2it/s 4:07<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.956      0.942       0.98      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      3.29G     0.7945     0.3842     0.9528        113        640: 100% ━━━━━━━━━━━━ 1276/1276 5.2it/s 4:07<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.957      0.942       0.98       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      3.29G     0.7907     0.3797     0.9539        102        640: 100% ━━━━━━━━━━━━ 1276/1276 5.2it/s 4:06<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                    all       1939      17899      0.956      0.942       0.98       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      3.29G     0.7837     0.3756     0.9506         86        640: 100% ━━━━━━━━━━━━ 1276/1276 5.2it/s 4:06<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.2it/s 11.7s0.2s
#                    all       1939      17899      0.958      0.942       0.98       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      3.29G     0.7769     0.3711     0.9455         69        640: 100% ━━━━━━━━━━━━ 1276/1276 5.2it/s 4:05<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 5.1it/s 12.0s0.2s
#                    all       1939      17899      0.958      0.942       0.98      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      3.29G     0.7721     0.3686     0.9443        131        640: 100% ━━━━━━━━━━━━ 1276/1276 5.2it/s 4:06<0.1s
# ...
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.17863,     0.17863,     0.28283, ...,           1,           1,           1],
#        [    0.34845,     0.34845,     0.41847, ...,           1,           1,           1],
#        [    0.20432,     0.20432,      0.2697, ...,           1,           1,           1],
#        [    0.42619,     0.42619,     0.53957, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.99679,     0.99679,     0.99359, ...,           0,           0,           0],
#        [    0.99728,     0.99728,     0.99667, ...,           0,           0,           0],
#        [    0.99261,     0.99261,     0.98891, ...,           0,           0,           0],
#        [    0.99735,     0.99735,     0.99669, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: 0.8508972931786731
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.86233,     0.81748,     0.81447,     0.90931])
# names: {0: 'bus', 1: 'car', 2: 'truck', 3: 'van'}
# nt_per_class: array([  312, 14723,  1353,  1511])
# nt_per_image: array([ 291, 1920,  860,  792])
# results_dict: {'metrics/precision(B)': 0.9597368419229102, 'metrics/recall(B)': 0.9419029650087802, 'metrics/mAP50(B)': 0.9805995396219868, 'metrics/mAP50-95(B)': 0.8508972931786731, 'fitness': 0.8508972931786731}
# save_dir: PosixPath('/kaggle/working/runs/exp_50')
# speed: {'preprocess': 0.21617213873682103, 'inference': 2.045472381630001, 'loss': 0.0003102841787070253, 'postprocess': 1.1017224074324787}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}

# %% [markdown]
# ## 3. Evaluation
# Extracting and comparing metrics.

# %%
def get_metrics(path):
    model = YOLO(path)
    m = model.val(data=working_yaml, device=device)
    return m.results_dict

m30 = get_metrics('/kaggle/working/runs/exp_30/weights/best.pt')
m50 = get_metrics('/kaggle/working/runs/exp_50/weights/best.pt')

labels = ['Precision', 'Recall', 'mAP@50', 'mAP@50-95']
v30 = [m30['metrics/precision(B)'], m30['metrics/recall(B)'], m30['metrics/mAP50(B)'], m30['metrics/mAP50-95(B)']]
v50 = [m50['metrics/precision(B)'], m50['metrics/recall(B)'], m50['metrics/mAP50(B)'], m50['metrics/mAP50-95(B)']]

x = np.arange(len(labels))
width = 0.35
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(x - width/2, v30, width, label='30 Epochs')
ax.bar(x + width/2, v50, width, label='50 Epochs')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_title('Performance Comparison (Full Dataset)')
ax.legend()
plt.show()
# Out:
# Ultralytics 8.4.42 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 113.0±38.0 MB/s, size: 59.8 KB)
# val: Scanning /kaggle/input/datasets/hossammostafa25/hosssssss/valid/labels... 1939 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1939/1939 610.3it/s 3.2s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/hossammostafa25/hosssssss/valid is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 122/122 7.0it/s 17.4s0.1s
#                    all       1939      17899      0.947      0.943      0.976       0.84
#                    bus        291        312      0.949      0.958      0.978      0.844
#                    car       1920      14723      0.956      0.942      0.984       0.81
#                  truck        860       1353      0.917      0.891       0.95      0.805
#                    van        792       1511      0.967      0.981      0.993        0.9
# Speed: 1.0ms preprocess, 3.7ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
# Ultralytics 8.4.42 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 64.9±45.0 MB/s, size: 52.1 KB)
# val: Scanning /kaggle/input/datasets/hossammostafa25/hosssssss/valid/labels... 1939 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1939/1939 1.1Kit/s 1.8s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/hossammostafa25/hosssssss/valid is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 122/122 6.8it/s 17.9s0.1s
#                    all       1939      17899      0.959      0.942      0.981      0.851
#                    bus        291        312      0.973      0.952      0.987       0.86
#                    car       1920      14723      0.964       0.94      0.986      0.819
#                  truck        860       1353      0.928      0.895      0.957      0.815
#                    van        792       1511      0.972       0.98      0.992      0.908
# Speed: 1.0ms preprocess, 3.7ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-2

# %% [markdown]
# ## 4. Inference and Traffic Analysis

# %%
class TrafficDetector:
    def __init__(self, model_path):
        self.model = YOLO(model_path)

    def process(self, img_path):
        res = self.model.predict(img_path, conf=0.25, verbose=False)[0]
        count = len(res.boxes)
        density = "LOW" if count <= 5 else "MEDIUM" if count <= 15 else "HIGH"
        return count, density, res.plot()

detector = TrafficDetector('/kaggle/working/runs/exp_50/weights/best.pt')
test_dir = dataset_input_dir / 'test/images'
test_imgs = list(test_dir.glob('*.jpg')) + list(test_dir.glob('*.png'))

if test_imgs:
    for i in range(min(5, len(test_imgs))):
        count, density, annotated = detector.process(str(test_imgs[i]))
        plt.figure(figsize=(8, 6))
        plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
        plt.title(f"Count: {count} | Density: {density}")
        plt.axis('off')
        plt.show()
else:
    print("No test images found.")

# %%
# ==============================
# Export All Results
# ==============================
import json
from pathlib import Path
import shutil
import cv2

# Create output folder
output_dir = Path('/kaggle/working/final_output')
output_dir.mkdir(exist_ok=True)

print("Saving results to:", output_dir)

# ------------------------------
# 1. Save Metrics
# ------------------------------
results = {
    "30_epochs": m30,
    "50_epochs": m50
}

with open(output_dir / 'metrics.json', 'w') as f:
    json.dump(results, f, indent=4)

print("Metrics saved")

# ------------------------------
# 2. Save Comparison Graph
# ------------------------------
fig.savefig(output_dir / 'comparison.png')
print("Graph saved")

# ------------------------------
# 3. Save Inference Images
# ------------------------------
for i in range(min(5, len(test_imgs))):
    count, density, annotated = detector.process(str(test_imgs[i]))

    save_path = output_dir / f"result_{i}.jpg"
    cv2.imwrite(str(save_path), annotated)

print("Inference images saved")

# ------------------------------
# 4. Copy Training Runs (models + logs)
# ------------------------------
runs_src = Path('/kaggle/working/runs')

if runs_src.exists():
    shutil.copytree(runs_src, output_dir / 'runs', dirs_exist_ok=True)
    print("Training runs copied")

# ------------------------------
# 5. Copy data.yaml
# ------------------------------
shutil.copy(working_yaml, output_dir / 'data.yaml')

# ------------------------------
# 6. Create ZIP file
# ------------------------------
zip_path = '/kaggle/working/project_results.zip'
shutil.make_archive('/kaggle/working/project_results', 'zip', output_dir)

print("ZIP file created at:", zip_path)
# Out:
# Saving results to: /kaggle/working/final_output
# Metrics saved
# Graph saved
# Inference images saved
# Training runs copied
# ZIP file created at: /kaggle/working/project_results.zip
